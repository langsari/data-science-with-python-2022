# %%
import pandas as pd

# %%
data = pd.read_excel("/Users/hilmanyusoh/Documents/GitHub/data-science-with-python-2022/dataset/titanic_to_excel.xlsx")

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data[["PassengerId","Survived"]][: 11]
# Out:
#     PassengerId  Survived
# 0             1         0
# 1             2         1
# 2             3         1
# 3             4         1
# 4             5         0
# 5             6         0
# 6             7         0
# 7             8         0
# 8             9         1
# 9            10         1
# 10           11         1

# %%
data1 = pd.read_csv("/Users/hilmanyusoh/Documents/GitHub/data-science-with-python-2022/dataset/titanic.csv")

# %%
data1.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data1[["PassengerId","Survived"]][: 11]
# Out:
#     PassengerId  Survived
# 0             1         0
# 1             2         1
# 2             3         1
# 3             4         1
# 4             5         0
# 5             6         0
# 6             7         0
# 7             8         0
# 8             9         1
# 9            10         1
# 10           11         1

# %%
data2 = pd.read_json("/Users/hilmanyusoh/Documents/GitHub/data-science-with-python-2022/dataset/en_translation_1.json")

# %%
data2.head(2)
# Out:
#                name  index                                            verse  \
# verse_1  al-Fatihah      1  In the name of God, the Gracious, the Merciful.
# verse_2  al-Fatihah      1            Praise be to God, Lord of the Worlds.
#
#          count
# verse_1      7
# verse_2      7

# %%
data2[["name","index"]][: 11]
# Out:
#                name  index
# verse_1  al-Fatihah      1
# verse_2  al-Fatihah      1
# verse_3  al-Fatihah      1
# verse_4  al-Fatihah      1
# verse_5  al-Fatihah      1
# verse_6  al-Fatihah      1
# verse_7  al-Fatihah      1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("/Users/hilmanyusoh/Documents/GitHub/data-science-with-python-2022/dataset/air_quality_no2.csv")

# %%
data.head(11)
# Out:
#                datetime  station_antwerp  station_paris  station_london
# 0   2019-05-07 02:00:00              NaN            NaN            23.0
# 1   2019-05-07 03:00:00             50.5           25.0            19.0
# 2   2019-05-07 04:00:00             45.0           27.7            19.0
# 3   2019-05-07 05:00:00              NaN           50.4            16.0
# 4   2019-05-07 06:00:00              NaN           61.9             NaN
# 5   2019-05-07 07:00:00              NaN           72.4            26.0
# 6   2019-05-07 08:00:00              NaN           77.7            32.0
# 7   2019-05-07 09:00:00              NaN           67.9            32.0
# 8   2019-05-07 10:00:00              NaN           56.0            28.0
# 9   2019-05-07 11:00:00              NaN           34.5            21.0
# 10  2019-05-07 12:00:00              NaN           20.1            21.0

# %%
data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.plot.area()
# Out:
# <AxesSubplot:>
